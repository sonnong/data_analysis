# %% [markdown]
# # Visualizing Earnings Based On College Majors

# %% [markdown]
# ## Data overview

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
recent_grads.describe()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# Dropping rows with missing values:

# %%
recent_grads = recent_grads.dropna()
#Check the number of remaining rows
print(len(recent_grads.index))
# Out:
# 172

# %% [markdown]
# There's only one row dropped.

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# We'll exlore relations between:
# - **Sample_size** and **Median**

# %%
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Sample_size vs. Median')

# %% [markdown]
# - **Sample_size** and **Unemployment_rate**

# %%
ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Sample_size vs. Unemployment_rate')

# %% [markdown]
# - **Full_time** and **Median**

# %%
ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Full_time vs. Median')

# %% [markdown]
# - **ShareWomen** and **Unemployment_rate**

# %%
ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='ShareWomen vs. Unemployment_rate')

# %% [markdown]
# - **Men** and **Median**

# %%
ax5 = recent_grads.plot(x='Men', y='Median', kind='scatter', title='Men vs. Median')

# %% [markdown]
# - **Women** and **Median**

# %%
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter', title='Women vs. Median')

# %% [markdown]
# **Conclusion:** There is no relationship discovered in the scatter plots.

# %% [markdown]
# ## Histograms

# %% [markdown]
# Let's explore the distributions of the following columns:
# - **Sample_size**

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0, 5000))

# %% [markdown]
# - **Median**

# %%
recent_grads['Median'].plot(kind='hist')

# %% [markdown]
# - **Employed**

# %%
recent_grads['Employed'].plot(kind='hist')

# %% [markdown]
# - **Full_time**

# %%
recent_grads['Full_time'].plot(kind='hist')

# %% [markdown]
# - **ShareWomen**

# %%
recent_grads['ShareWomen'].plot(kind='hist')

# %% [markdown]
# - **Unemployment_rate**

# %%
recent_grads['Unemployment_rate'].plot(kind='hist')

# %% [markdown]
# - **Men**

# %%
recent_grads['Men'].plot(kind='hist')

# %% [markdown]
# - **Women**

# %%
recent_grads['Women'].plot(kind='hist')

# %% [markdown]
# Observations from the histograms:
# - More than half of majors are predominantly female
# - The most common median salary range is 30000 - 40000

# %% [markdown]
# ## Scatter Matrix Plots

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f94271acb00>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9426e3aef0>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bar plots

# %% [markdown]
# Comparing the percentages of women from the first ten rows and last ten rows:

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %% [markdown]
# Comparing the unemployment rate from the first ten rows and last ten rows:

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate')
